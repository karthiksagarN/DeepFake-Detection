# %%
#THis code is to check if the video is corrupted.
#If the video is corrupted delete the video manually.
import glob
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition

#Check if the file is corrupted or not
def validate_video(vid_path,train_transforms):
      transform = train_transforms
      count = 20
      video_path = vid_path
      frames = []
      a = int(100/count)
      first_frame = np.random.randint(0,a)
      temp_video = video_path.split('/')[-1]
      for i,frame in enumerate(frame_extract(video_path)):
        frames.append(transform(frame))
        if(len(frames) == count):
          break
      frames = torch.stack(frames)
      frames = frames[:count]
      return frames

#extract a from from video
def frame_extract(path):
  vidObj = cv2.VideoCapture(path) 
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image

im_size = 112
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transforms = transforms.Compose([transforms.ToPILImage(),
                                      transforms.Resize((im_size,im_size)),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean,std)])
video_file =  glob.glob('/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data-Real/*.mp4')
video_file += glob.glob('/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data-Fake/*.mp4')
# video_file += glob.glob('/content/drive/My Drive/DFDC_FAKE_Face_only_data/*.mp4')
# video_file += glob.glob('/content/drive/My Drive/DFDC_REAL_Face_only_data/*.mp4')
# video_file += glob.glob('/content/drive/My Drive/FF_Face_only_data/*.mp4')
print("Total no of videos :" , len(video_file))
print(video_file)
count = 0
for i in video_file:
  try:
    count+=1
    validate_video(i,train_transforms)
  except:
    print("Number of video processed: " , count ," Remaining : " , (len(video_file) - count))
    print("Corrupted video is : " , i)
    continue
print((len(video_file) - count))
# Out:
# Total no of videos: 299
# ['/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0002.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0007.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0001.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0013.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0007.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0005.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0004.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0006.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0006.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0012.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0006.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0000.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0009.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0003.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0008.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0008.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0001.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0010.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0004.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0002.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0004.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0004.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0006.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0007.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0005.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0003.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0005.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0011.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0005.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0000.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0009.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0009.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0004.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0001.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0015.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0001.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0007.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0003.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0001.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0009.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0000.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0002.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0000.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0006.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0000.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0014.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0005.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0008.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0004.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0002.mp4', '/Users/karthiksagar/Deep-Fake-Detection/Celeb-Fac ...
# Number of video processed: 1  Remaining: 298
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0002.mp4
# Number of video processed: 2  Remaining: 297
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0007.mp4
# Number of video processed: 3  Remaining: 296
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0001.mp4
# Number of video processed: 4  Remaining: 295
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0013.mp4
# Number of video processed: 5  Remaining: 294
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0007.mp4
# Number of video processed: 6  Remaining: 293
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0005.mp4
# Number of video processed: 7  Remaining: 292
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0004.mp4
# Number of video processed: 8  Remaining: 291
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0006.mp4
# Number of video processed: 9  Remaining: 290
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0006.mp4
# Number of video processed: 10  Remaining: 289
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0012.mp4
# Number of video processed: 11  Remaining: 288
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0006.mp4
# Number of video processed: 12  Remaining: 287
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0000.mp4
# Number of video processed: 13  Remaining: 286
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0009.mp4
# Number of video processed: 14  Remaining: 285
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0003.mp4
# Number of video processed: 15  Remaining: 284
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0008.mp4
# Number of video processed: 16  Remaining: 283
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0008.mp4
# Number of video processed: 17  Remaining: 282
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0001.mp4
# Number of video processed: 18  Remaining: 281
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0010.mp4
# Number of video processed: 19  Remaining: 280
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0004.mp4
# Number of video processed: 20  Remaining: 279
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0002.mp4
# Number of video processed: 21  Remaining: 278
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0004.mp4
# Number of video processed: 22  Remaining: 277
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0004.mp4
# Number of video processed: 23  Remaining: 276
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0006.mp4
# Number of video processed: 24  Remaining: 275
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0007.mp4
# Number of video processed: 25  Remaining: 274
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0005.mp4
# Number of video processed: 26  Remaining: 273
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0003.mp4
# Number of video processed: 27  Remaining: 272
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0005.mp4
# Number of video processed: 28  Remaining: 271
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0011.mp4
# Number of video processed: 29  Remaining: 270
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0005.mp4
# Number of video processed: 30  Remaining: 269
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0000.mp4
# Number of video processed: 31  Remaining: 268
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0009.mp4
# Number of video processed: 32  Remaining: 267
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0009.mp4
# Number of video processed: 33  Remaining: 266
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0004.mp4
# Number of video processed: 34  Remaining: 265
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0001.mp4
# Number of video processed: 35  Remaining: 264
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0015.mp4
# Number of video processed: 36  Remaining: 263
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0001.mp4
# Number of video processed: 37  Remaining: 262
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0007.mp4
# Number of video processed: 38  Remaining: 261
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0003.mp4
# Number of video processed: 39  Remaining: 260
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0001.mp4
# Number of video processed: 40  Remaining: 259
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0009.mp4
# Number of video processed: 41  Remaining: 258
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0000.mp4
# Number of video processed: 42  Remaining: 257
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0002.mp4
# Number of video processed: 43  Remaining: 256
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0000.mp4
# Number of video processed: 44  Remaining: 255
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0006.mp4
# Number of video processed: 45  Remaining: 254
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0000.mp4
# Number of video processed: 46  Remaining: 253
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0014.mp4
# Number of video processed: 47  Remaining: 252
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0005.mp4
# Number of video processed: 48  Remaining: 251
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0008.mp4
# Number of video processed: 49  Remaining: 250
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0004.mp4
# Number of video processed: 50  Remaining: 249
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0002.mp4
# Number of video processed: 51  Remaining: 248
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0002.mp4
# Number of video processed: 52  Remaining: 247
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0000.mp4
# Number of video processed: 53  Remaining: 246
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0002.mp4
# Number of video processed: 54  Remaining: 245
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0003.mp4
# Number of video processed: 55  Remaining: 244
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0001.mp4
# Number of video processed: 56  Remaining: 243
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0003.mp4
# Number of video processed: 57  Remaining: 242
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0005.mp4
# Number of video processed: 58  Remaining: 241
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0003.mp4
# Number of video processed: 59  Remaining: 240
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0006.mp4
# Number of video processed: 60  Remaining: 239
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0009.mp4
# Number of video processed: 61  Remaining: 238
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0000.mp4
# Number of video processed: 62  Remaining: 237
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0007.mp4
# Number of video processed: 63  Remaining: 236
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0007.mp4
# Number of video processed: 64  Remaining: 235
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0004.mp4
# Number of video processed: 65  Remaining: 234
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0004.mp4
# Number of video processed: 66  Remaining: 233
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0007.mp4
# Number of video processed: 67  Remaining: 232
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0009.mp4
# Number of video processed: 68  Remaining: 231
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0006.mp4
# Number of video processed: 69  Remaining: 230
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0006.mp4
# Number of video processed: 70  Remaining: 229
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0004.mp4
# Number of video processed: 71  Remaining: 228
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0004.mp4
# Number of video processed: 72  Remaining: 227
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0003.mp4
# Number of video processed: 73  Remaining: 226
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0003.mp4
# Number of video processed: 74  Remaining: 225
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0008.mp4
# Number of video processed: 75  Remaining: 224
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0002.mp4
# Number of video processed: 76  Remaining: 223
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0009.mp4
# Number of video processed: 77  Remaining: 222
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0002.mp4
# Number of video processed: 78  Remaining: 221
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0009.mp4
# Number of video processed: 79  Remaining: 220
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0005.mp4
# Number of video processed: 80  Remaining: 219
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0005.mp4
# Number of video processed: 81  Remaining: 218
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0007.mp4
# Number of video processed: 82  Remaining: 217
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0007.mp4
# Number of video processed: 83  Remaining: 216
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0006.mp4
# Number of video processed: 84  Remaining: 215
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0005.mp4
# Number of video processed: 85  Remaining: 214
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0005.mp4
# Number of video processed: 86  Remaining: 213
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0006.mp4
# Number of video processed: 87  Remaining: 212
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0006.mp4
# Number of video processed: 88  Remaining: 211
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0001.mp4
# Number of video processed: 89  Remaining: 210
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0003.mp4
# Number of video processed: 90  Remaining: 209
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0004.mp4
# Number of video processed: 91  Remaining: 208
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0004.mp4
# Number of video processed: 92  Remaining: 207
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0008.mp4
# Number of video processed: 93  Remaining: 206
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0008.mp4
# Number of video processed: 94  Remaining: 205
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0007.mp4
# Number of video processed: 95  Remaining: 204
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0007.mp4
# Number of video processed: 96  Remaining: 203
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0005.mp4
# Number of video processed: 97  Remaining: 202
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0005.mp4
# Number of video processed: 98  Remaining: 201
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0007.mp4
# Number of video processed: 99  Remaining: 200
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0007.mp4
# Number of video processed: 100  Remaining: 199
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0000.mp4
# Number of video processed: 101  Remaining: 198
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0000.mp4
# Number of video processed: 102  Remaining: 197
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0001.mp4
# Number of video processed: 103  Remaining: 196
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0001.mp4
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0013.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0012.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0010.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0011.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0015.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0014.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id12_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0006.mp4"
# Number of video processed: 104  Remaining: 195
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0006.mp4
# Number of video processed: 105  Remaining: 194
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0006.mp4
# Number of video processed: 106  Remaining: 193
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0004.mp4
# Number of video processed: 107  Remaining: 192
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0004.mp4
# Number of video processed: 108  Remaining: 191
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0005.mp4
# Number of video processed: 109  Remaining: 190
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0006.mp4
# Number of video processed: 110  Remaining: 189
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0006.mp4
# Number of video processed: 111  Remaining: 188
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0009.mp4
# Number of video processed: 112  Remaining: 187
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0009.mp4
# Number of video processed: 113  Remaining: 186
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0005.mp4
# Number of video processed: 114  Remaining: 185
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0005.mp4
# Number of video processed: 115  Remaining: 184
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0002.mp4
# Number of video processed: 116  Remaining: 183
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0006.mp4
# Number of video processed: 117  Remaining: 182
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0001.mp4
# Number of video processed: 118  Remaining: 181
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0001.mp4
# Number of video processed: 119  Remaining: 180
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0002.mp4
# Number of video processed: 120  Remaining: 179
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0002.mp4
# Number of video processed: 121  Remaining: 178
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0001.mp4
# Number of video processed: 122  Remaining: 177
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0002.mp4
# Number of video processed: 123  Remaining: 176
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0002.mp4
# Number of video processed: 124  Remaining: 175
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0000.mp4
# Number of video processed: 125  Remaining: 174
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0000.mp4
# Number of video processed: 126  Remaining: 173
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0005.mp4
# Number of video processed: 127  Remaining: 172
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0005.mp4
# Number of video processed: 128  Remaining: 171
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0004.mp4
# Number of video processed: 129  Remaining: 170
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0004.mp4
# Number of video processed: 130  Remaining: 169
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0001.mp4
# Number of video processed: 131  Remaining: 168
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0001.mp4
# Number of video processed: 132  Remaining: 167
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0003.mp4
# Number of video processed: 133  Remaining: 166
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0003.mp4
# Number of video processed: 134  Remaining: 165
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0000.mp4
# Number of video processed: 135  Remaining: 164
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0003.mp4
# Number of video processed: 136  Remaining: 163
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0003.mp4
# Number of video processed: 137  Remaining: 162
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0000.mp4
# Number of video processed: 138  Remaining: 161
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0000.mp4
# Number of video processed: 139  Remaining: 160
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0007.mp4
# Number of video processed: 140  Remaining: 159
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id6_0009.mp4
# Number of video processed: 141  Remaining: 158
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0005.mp4
# Number of video processed: 142  Remaining: 157
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0002.mp4
# Number of video processed: 143  Remaining: 156
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0002.mp4
# Number of video processed: 144  Remaining: 155
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0008.mp4
# Number of video processed: 145  Remaining: 154
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0008.mp4
# Number of video processed: 146  Remaining: 153
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0001.mp4
# Number of video processed: 147  Remaining: 152
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0001.mp4
# Number of video processed: 148  Remaining: 151
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0002.mp4
# Number of video processed: 149  Remaining: 150
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0001.mp4
# Number of video processed: 150  Remaining: 149
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0001.mp4
# Number of video processed: 151  Remaining: 148
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0003.mp4
# Number of video processed: 152  Remaining: 147
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0003.mp4
# Number of video processed: 153  Remaining: 146
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0006.mp4
# Number of video processed: 154  Remaining: 145
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0006.mp4
# Number of video processed: 155  Remaining: 144
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0007.mp4
# Number of video processed: 156  Remaining: 143
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0007.mp4
# Number of video processed: 157  Remaining: 142
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0002.mp4
# Number of video processed: 158  Remaining: 141
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0002.mp4
# Number of video processed: 159  Remaining: 140
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0000.mp4
# Number of video processed: 160  Remaining: 139
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0000.mp4
# Number of video processed: 161  Remaining: 138
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0003.mp4
# Number of video processed: 162  Remaining: 137
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0000.mp4
# Number of video processed: 163  Remaining: 136
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0000.mp4
# Number of video processed: 164  Remaining: 135
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0009.mp4
# Number of video processed: 165  Remaining: 134
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0009.mp4
# Number of video processed: 166  Remaining: 133
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0003.mp4
# Number of video processed: 167  Remaining: 132
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0003.mp4
# Number of video processed: 168  Remaining: 131
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0004.mp4
# Number of video processed: 169  Remaining: 130
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id6_0007.mp4
# Number of video processed: 170  Remaining: 129
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0009.mp4
# Number of video processed: 171  Remaining: 128
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0002.mp4
# Number of video processed: 172  Remaining: 127
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0004.mp4
# Number of video processed: 173  Remaining: 126
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0002.mp4
# Number of video processed: 174  Remaining: 125
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0004.mp4
# Number of video processed: 175  Remaining: 124
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0000.mp4
# Number of video processed: 176  Remaining: 123
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0001.mp4
# Number of video processed: 177  Remaining: 122
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0001.mp4
# Number of video processed: 178  Remaining: 121
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0000.mp4
# Number of video processed: 179  Remaining: 120
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0000.mp4
# Number of video processed: 180  Remaining: 119
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0001.mp4
# Number of video processed: 181  Remaining: 118
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0003.mp4
# Number of video processed: 182  Remaining: 117
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0005.mp4
# Number of video processed: 183  Remaining: 116
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0003.mp4
# Number of video processed: 184  Remaining: 115
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0005.mp4
# Number of video processed: 185  Remaining: 114
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id6_0006.mp4
# Number of video processed: 186  Remaining: 113
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0007.mp4
# Number of video processed: 187  Remaining: 112
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0001.mp4
# Number of video processed: 188  Remaining: 111
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0007.mp4
# Number of video processed: 189  Remaining: 110
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0003.mp4
# Number of video processed: 190  Remaining: 109
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id2_0009.mp4
# Number of video processed: 191  Remaining: 108
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0002.mp4
# Number of video processed: 192  Remaining: 107
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id3_0009.mp4
# Number of video processed: 193  Remaining: 106
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0002.mp4
# Number of video processed: 194  Remaining: 105
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0003.mp4
# Number of video processed: 195  Remaining: 104
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0003.mp4
# Number of video processed: 196  Remaining: 103
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0002.mp4
# Number of video processed: 197  Remaining: 102
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0006.mp4
# Number of video processed: 198  Remaining: 101
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0000.mp4
# Number of video processed: 199  Remaining: 100
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0006.mp4
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id9_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0000.mp4"
# ...
# Number of video processed: 274  Remaining: 25
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0000.mp4
# Number of video processed: 275  Remaining: 24
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0004.mp4
# Number of video processed: 276  Remaining: 23
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0002.mp4
# Number of video processed: 277  Remaining: 22
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0004.mp4
# Number of video processed: 278  Remaining: 21
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0007.mp4
# Number of video processed: 279  Remaining: 20
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0008.mp4
# Number of video processed: 280  Remaining: 19
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0008.mp4
# Number of video processed: 281  Remaining: 18
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0000.mp4
# Number of video processed: 282  Remaining: 17
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0001.mp4
# Number of video processed: 283  Remaining: 16
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0009.mp4
# Number of video processed: 284  Remaining: 15
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0006.mp4
# Number of video processed: 285  Remaining: 14
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0003.mp4
# Number of video processed: 286  Remaining: 13
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0005.mp4
# Number of video processed: 287  Remaining: 12
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0005.mp4
# Number of video processed: 288  Remaining: 11
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0007.mp4
# Number of video processed: 289  Remaining: 10
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0001.mp4
# Number of video processed: 290  Remaining: 9
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0007.mp4
# Number of video processed: 291  Remaining: 8
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id17_0001.mp4
# Number of video processed: 292  Remaining: 7
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0009.mp4
# Number of video processed: 293  Remaining: 6
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0003.mp4
# Number of video processed: 294  Remaining: 5
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0002.mp4
# Number of video processed: 295  Remaining: 4
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0005.mp4
# Number of video processed: 296  Remaining: 3
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0006.mp4
# Number of video processed: 297  Remaining: 2
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id17_0000.mp4
# Number of video processed: 298  Remaining: 1
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0006.mp4
# Number of video processed: 299  Remaining: 0
# Corrupted video is: /Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0000.mp4
# Number of corrupted videos deleted: 0
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id6_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0008.mp4"
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x2a4cc4ac0] moov atom not found
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0010.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id16_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id17_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id9_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id3_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id6_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id6_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id17_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id16_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id9_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id8_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id6_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id3_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id2_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id6_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id11_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id7_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id10_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0010.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id4_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0011.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0013.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id4_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0012.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0004.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id2_id0_0008.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id13_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0007.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id17_0001.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id4_0009.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0003.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_id0_0002.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_id1_0005.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id0_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id17_0000.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id1_0006.mp4"
# OpenCV: Couldn't read video stream from file "/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/id16_0000.mp4"

# %%
#to load preprocessod video to memory
import json
import glob
import numpy as np
import cv2
import copy
import random
video_files = glob.glob('/Users/karthiksagar/Deep-Fake-Detection/Celeb-Face-Only-Data/*.mp4')
# video_files += glob.glob('/content/drive/My Drive/Celeb_real_face_only/*.mp4')
# video_files += glob.glob('/content/drive/My Drive/DFDC_FAKE_Face_only_data/*.mp4')
# video_files += glob.glob('/content/drive/My Drive/DFDC_REAL_Face_only_data/*.mp4')
# video_files += glob.glob('/content/drive/My Drive/FF_Face_only_data/*.mp4')
random.shuffle(video_files)
random.shuffle(video_files)
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<100):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames are " , frame_count)
print("Total no of video: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))

# %%
# load the video name and labels from csv
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
class video_dataset(Dataset):
    def __init__(self,video_names,labels,sequence_length = 60,transform = None):
        self.video_names = video_names
        self.labels = labels
        self.transform = transform
        self.count = sequence_length
    def __len__(self):
        return len(self.video_names)
    def __getitem__(self,idx):
        video_path = self.video_names[idx]
        frames = []
        a = int(100/self.count)
        first_frame = np.random.randint(0,a)
        temp_video = video_path.split('/')[-1]
        #print(temp_video)
        label = self.labels.iloc[(labels.loc[labels["file"] == temp_video].index.values[0]),1]
        if(label == 'FAKE'):
          label = 0
        if(label == 'REAL'):
          label = 1
        for i,frame in enumerate(self.frame_extract(video_path)):
          frames.append(self.transform(frame))
          if(len(frames) == self.count):
            break
        frames = torch.stack(frames)
        frames = frames[:self.count]
        #print("length:" , len(frames), "label",label)
        return frames,label
    def frame_extract(self,path):
      vidObj = cv2.VideoCapture(path) 
      success = 1
      while success:
          success, image = vidObj.read()
          if success:
              yield image
#plot the image
def im_plot(tensor):
    image = tensor.cpu().numpy().transpose(1,2,0)
    b,g,r = cv2.split(image)
    image = cv2.merge((r,g,b))
    image = image*[0.22803, 0.22145, 0.216989] +  [0.43216, 0.394666, 0.37645]
    image = image*255.0
    plt.imshow(image.astype(int))
    plt.show()

# %%
#count the number of fake and real videos
def number_of_real_and_fake_videos(data_list):
  header_list = ["file","label"]
  lab = pd.read_csv('/content/drive/My Drive/Gobal_metadata.csv',names=header_list)
  fake = 0
  real = 0
  for i in data_list:
    temp_video = i.split('/')[-1]
    label = lab.iloc[(labels.loc[labels["file"] == temp_video].index.values[0]),1]
    if(label == 'FAKE'):
      fake+=1
    if(label == 'REAL'):
      real+=1
  return real,fake

# %%
# load the labels and video in data loader
import random
import pandas as pd
from sklearn.model_selection import train_test_split

header_list = ["file","label"]
labels = pd.read_csv('/content/drive/My Drive/Gobal_metadata.csv',names=header_list)
#print(labels)
train_videos = video_files[:int(0.8*len(video_files))]
valid_videos = video_files[int(0.8*len(video_files)):]
print("train : " , len(train_videos))
print("test : " , len(valid_videos))
# train_videos,valid_videos = train_test_split(data,test_size = 0.2)
# print(train_videos)

print("TRAIN: ", "Real:",number_of_real_and_fake_videos(train_videos)[0]," Fake:",number_of_real_and_fake_videos(train_videos)[1])
print("TEST: ", "Real:",number_of_real_and_fake_videos(valid_videos)[0]," Fake:",number_of_real_and_fake_videos(valid_videos)[1])


im_size = 112
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transforms = transforms.Compose([
                                        transforms.ToPILImage(),
                                        transforms.Resize((im_size,im_size)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean,std)])

test_transforms = transforms.Compose([
                                        transforms.ToPILImage(),
                                        transforms.Resize((im_size,im_size)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean,std)])
train_data = video_dataset(train_videos,labels,sequence_length = 10,transform = train_transforms)
#print(train_data)
val_data = video_dataset(valid_videos,labels,sequence_length = 10,transform = train_transforms)
train_loader = DataLoader(train_data,batch_size = 4,shuffle = True,num_workers = 4)
valid_loader = DataLoader(val_data,batch_size = 4,shuffle = True,num_workers = 4)
image,label = train_data[0]
im_plot(image[0,:,:,:])

# %%
#Model with feature visualization
from torch import nn
from torchvision import models
class Model(nn.Module):
    def __init__(self, num_classes,latent_dim= 2048, lstm_layers=1 , hidden_dim = 2048, bidirectional = False):
        super(Model, self).__init__()
        model = models.resnext50_32x4d(pretrained = True) #Residual Network CNN
        self.model = nn.Sequential(*list(model.children())[:-2])
        self.lstm = nn.LSTM(latent_dim,hidden_dim, lstm_layers,  bidirectional)
        self.relu = nn.LeakyReLU()
        self.dp = nn.Dropout(0.4)
        self.linear1 = nn.Linear(2048,num_classes)
        self.avgpool = nn.AdaptiveAvgPool2d(1)
    def forward(self, x):
        batch_size,seq_length, c, h, w = x.shape
        x = x.view(batch_size * seq_length, c, h, w)
        fmap = self.model(x)
        x = self.avgpool(fmap)
        x = x.view(batch_size,seq_length,2048)
        x_lstm,_ = self.lstm(x,None)
        return fmap,self.dp(self.linear1(torch.mean(x_lstm,dim = 1)))

# %%
model = Model(2).cuda()
a,b = model(torch.from_numpy(np.empty((1,20,3,112,112))).type(torch.cuda.FloatTensor))

# %%
import torch
from torch.autograd import Variable
import time
import os
import sys
import os
def train_epoch(epoch, num_epochs, data_loader, model, criterion, optimizer):
    model.train()
    losses = AverageMeter()
    accuracies = AverageMeter()
    t = []
    for i, (inputs, targets) in enumerate(data_loader):
        if torch.cuda.is_available():
            targets = targets.type(torch.cuda.LongTensor)
            inputs = inputs.cuda()
        _,outputs = model(inputs)
        loss  = criterion(outputs,targets.type(torch.cuda.LongTensor))
        acc = calculate_accuracy(outputs, targets.type(torch.cuda.LongTensor))
        losses.update(loss.item(), inputs.size(0))
        accuracies.update(acc, inputs.size(0))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sys.stdout.write(
                "\r[Epoch %d/%d] [Batch %d / %d] [Loss: %f, Acc: %.2f%%]"
                % (
                    epoch,
                    num_epochs,
                    i,
                    len(data_loader),
                    losses.avg,
                    accuracies.avg))
    torch.save(model.state_dict(),'/content/checkpoint.pt')
    return losses.avg,accuracies.avg
def test(epoch,model, data_loader ,criterion):
    print('Testing')
    model.eval()
    losses = AverageMeter()
    accuracies = AverageMeter()
    pred = []
    true = []
    count = 0
    with torch.no_grad():
        for i, (inputs, targets) in enumerate(data_loader):
            if torch.cuda.is_available():
                targets = targets.cuda().type(torch.cuda.FloatTensor)
                inputs = inputs.cuda()
            _,outputs = model(inputs)
            loss = torch.mean(criterion(outputs, targets.type(torch.cuda.LongTensor)))
            acc = calculate_accuracy(outputs,targets.type(torch.cuda.LongTensor))
            _,p = torch.max(outputs,1) 
            true += (targets.type(torch.cuda.LongTensor)).detach().cpu().numpy().reshape(len(targets)).tolist()
            pred += p.detach().cpu().numpy().reshape(len(p)).tolist()
            losses.update(loss.item(), inputs.size(0))
            accuracies.update(acc, inputs.size(0))
            sys.stdout.write(
                    "\r[Batch %d / %d]  [Loss: %f, Acc: %.2f%%]"
                    % (
                        i,
                        len(data_loader),
                        losses.avg,
                        accuracies.avg
                        )
                    )
        print('\nAccuracy {}'.format(accuracies.avg))
    return true,pred,losses.avg,accuracies.avg
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()
    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
def calculate_accuracy(outputs, targets):
    batch_size = targets.size(0)

    _, pred = outputs.topk(1, 1, True)
    pred = pred.t()
    correct = pred.eq(targets.view(1, -1))
    n_correct_elems = correct.float().sum().item()
    return 100* n_correct_elems / batch_size

# %%
import seaborn as sn
#Output confusion matrix
def print_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    print('True positive = ', cm[0][0])
    print('False positive = ', cm[0][1])
    print('False negative = ', cm[1][0])
    print('True negative = ', cm[1][1])
    print('\n')
    df_cm = pd.DataFrame(cm, range(2), range(2))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
    plt.ylabel('Actual label', size = 20)
    plt.xlabel('Predicted label', size = 20)
    plt.xticks(np.arange(2), ['Fake', 'Real'], size = 16)
    plt.yticks(np.arange(2), ['Fake', 'Real'], size = 16)
    plt.ylim([2, 0])
    plt.show()
    calculated_acc = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+ cm[1][1])
    print("Calculated Accuracy",calculated_acc*100)

# %%
def plot_loss(train_loss_avg,test_loss_avg,num_epochs):
  loss_train = train_loss_avg
  loss_val = test_loss_avg
  print(num_epochs)
  epochs = range(1,num_epochs+1)
  plt.plot(epochs, loss_train, 'g', label='Training loss')
  plt.plot(epochs, loss_val, 'b', label='validation loss')
  plt.title('Training and Validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()
def plot_accuracy(train_accuracy,test_accuracy,num_epochs):
  loss_train = train_accuracy
  loss_val = test_accuracy
  epochs = range(1,num_epochs+1)
  plt.plot(epochs, loss_train, 'g', label='Training accuracy')
  plt.plot(epochs, loss_val, 'b', label='validation accuracy')
  plt.title('Training and Validation accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.show()

# %%
from sklearn.metrics import confusion_matrix
#learning rate
lr = 1e-5#0.001
#number of epochs 
num_epochs = 20

optimizer = torch.optim.Adam(model.parameters(), lr= lr,weight_decay = 1e-5)

#class_weights = torch.from_numpy(np.asarray([1,15])).type(torch.FloatTensor).cuda()
#criterion = nn.CrossEntropyLoss(weight = class_weights).cuda()
criterion = nn.CrossEntropyLoss().cuda()
train_loss_avg =[]
train_accuracy = []
test_loss_avg = []
test_accuracy = []
for epoch in range(1,num_epochs+1):
    l, acc = train_epoch(epoch,num_epochs,train_loader,model,criterion,optimizer)
    train_loss_avg.append(l)
    train_accuracy.append(acc)
    true,pred,tl,t_acc = test(epoch,model,valid_loader,criterion)
    test_loss_avg.append(tl)
    test_accuracy.append(t_acc)
plot_loss(train_loss_avg,test_loss_avg,len(train_loss_avg))
plot_accuracy(train_accuracy,test_accuracy,len(train_accuracy))
print(confusion_matrix(true,pred))
print_confusion_matrix(true,pred)
